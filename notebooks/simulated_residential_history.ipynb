# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os

# %%
# locate the file types
shp_dir = os.path.join(os.getcwd(), '..', 'output/HIFLD/centroids')
file_types = [x for x in os.listdir(shp_dir) if not x.endswith('.csv')]

# %%
# test find the shapefile name
[each for each in os.listdir(os.path.join(shp_dir, file_types[0])) if each.endswith('.shp')]
# Out:
# ['FDIC_Insured_Banks_Sample.shp']

# %%
file_types
# Out:
# ['FDIC_Insured_Banks_Sample',
#  'Fire_Stations',
#  'PublicSchools_Sample',
#  'FDIC_Insured_Banks',
#  'AllPlacesOfWorship',
#  'Hospitals',
#  'CollegesUniversities',
#  'UrgentCareFacs',
#  'PublicSchools',
#  'Prison_Boundaries',
#  'AllPlacesofWorship_Sample']

# %%
# random read 
for eachfiletype in file_types:
    # locate the shp file
    shp_src = os.path.join(shp_dir, 
                           eachfiletype, 
                           [each for each in os.listdir(os.path.join(shp_dir, eachfiletype)) if each.endswith('.shp')][0])
    if 'random_reads' not in locals():
        random_reads = gpd.read_file(shp_src)
    else:
        random_reads = random_reads.append(gpd.read_file(shp_src))

    print(eachfiletype, random_reads.shape[0])
    
print(random_reads.shape[0])
# Out:
# FDIC_Insured_Banks_Sample 14206
# Fire_Stations 19206
# PublicSchools_Sample 33412
# FDIC_Insured_Banks 38412
# AllPlacesOfWorship 43412
# Hospitals 48412
# CollegesUniversities 53412
# UrgentCareFacs 58222
# PublicSchools 63222
# Prison_Boundaries 68222
# AllPlacesofWorship_Sample 91116
# 91116

# %%
# randomize order
tmp = random_reads.sample(random_state=100, n=20000)\
    .drop('Place_type', axis=1)

# assign user
np.random.seed(seed=10)
tmp['user_id'] = np.random.choice(np.arange(start=1, stop=5000, step=1), 
                                  20000, 
                                  replace=True)

# assign location start
dr = pd.date_range(start='2000-01-01', end='2024-01-01', freq='D')

np.random.seed(seed=11)
tmp['start_date'] = np.random.choice(dr, 20000, replace=True)

np.random.seed(seed=12)
tmp['end_duration']=np.random.choice(np.arange(365,1000), 20000, replace=True).astype('timedelta64[D]')
tmp['end_date'] = tmp.apply(lambda x: x.start_date+x.end_duration, axis=1)

# %%
tmp
# Out:
#                                              Full_Addre  source_lon  \
# 10600                 PO BOX 100, FORT THOMAS, AZ 85536 -109.964432
# 409    30 North Lasalle Street, Chicago, Illinois 60602  -87.632478
# 12242                315 W. 5TH STREET, BOWIE, AZ 85605 -109.489800
# 986               702 BELMONT RD, GRAND FORKS, ND 58201  -97.028822
# 7230             5010 E SCHOOL STREET, DUGWAY, UT 84022 -112.747705
# ...                                                 ...         ...
# 305           Old Mathis Hollow Road, Stewart, TN 37175  -87.907534
# 4628                 65 WATTS LANE, THOMASTON, ME 04861  -69.183878
# 3291     10901 LITTLE PATUXENT PKWY, COLUMBIA, MD 21044  -76.878430
# 6398              PO BOX 70269, SALT LAKE CTY, UT 84170 -111.996615
# 1399           133 Grand Avenue, Paonia, Colorado 81428 -107.597824
#
#        source_lat                     geometry  user_id start_date  \
# 10600   33.037331  POINT (-109.96443 33.03733)     1290 2010-05-03
# 409     41.882829   POINT (-87.63248 41.88283)     4624 2014-03-28
# 12242   32.325286  POINT (-109.48980 32.32529)     1345 2019-11-16
# 986     47.915079   POINT (-97.02882 47.91508)     3442 2011-01-06
# 7230    40.226383  POINT (-112.74770 40.22638)     1181 2003-07-17
# ...           ...                          ...      ...        ...
# 305     36.316666   POINT (-87.90753 36.31667)     3304 2003-03-20
# 4628    44.082946   POINT (-69.18388 44.08295)     3568 2002-05-28
# 3291    39.211569   POINT (-76.87843 39.21157)     2662 2008-02-08
# 6398    40.742710  POINT (-111.99662 40.74271)      121 2006-12-07
# 1399    38.866130  POINT (-107.59782 38.86613)     1372 2017-12-13
#
#       end_duration   end_date
# 10600     755 days 2012-05-27
# 409       618 days 2015-12-06
# 12242     606 days 2021-07-14
# 986       624 days 2012-09-21
# 7230      797 days 2005-09-21
# ...            ...        ...
# 305       861 days 2005-07-28
# 4628      722 days 2004-05-19
# 3291      406 days 2009-03-20
# 6398      548 days 2008-06-07
# 1399      842 days 2020-04-03
#
# [20000 rows x 8 columns]

# %%
# quick print
tmp.sort_values(['user_id','start_date'])
# Out:
#                                        Full_Addre  source_lon  source_lat  \
# 6972          18248 HILLSIDE LN, DOLAND, SD 57436  -98.048963   44.737366
# 1940              244 ELM ST, HILL CITY, SD 57745 -103.574269   43.932597
# 7425                  PO BOX 9823, BEND, OR 97708 -121.344782   43.978130
# 634     10208 Bluegrass Road, Knoxville, TN 37922  -84.106168   35.860066
# 14075  7338 SOUTH ALTON WAY, CENTENNIAL, CO 80112 -104.882937   39.583518
# ...                                           ...         ...         ...
# 6784         1057 LINCOLN ST SW, ALBANY, OR 97321 -123.122892   44.627669
# 2045             384 COURT ST, PLYMOUTH, MA 02360  -70.691150   41.978494
# 2602         5037 32ND AVE, HUDSONVILLE, MI 49426  -85.862753   42.861220
# 3648     2525 GLENN HENDREN DR, LIBERTY, MO 64068  -94.424104   39.274506
# 2981       5700 N BRUCE ST, N LAS VEGAS, NV 89081 -115.124639   36.264440
#
#                           geometry  user_id start_date end_duration   end_date
# 6972    POINT (-98.04896 44.73737)        1 2004-12-09     604 days 2006-08-05
# 1940   POINT (-103.57427 43.93260)        1 2006-02-04     946 days 2008-09-07
# 7425   POINT (-121.34478 43.97813)        1 2018-07-12     456 days 2019-10-11
# 634     POINT (-84.10617 35.86007)        2 2001-05-11     790 days 2003-07-10
# 14075  POINT (-104.88294 39.58352)        2 2004-01-09     876 days 2006-06-03
# ...                            ...      ...        ...          ...        ...
# 6784   POINT (-123.12289 44.62767)     4999 2006-04-17     599 days 2007-12-07
# 2045    POINT (-70.69115 41.97849)     4999 2010-05-21     662 days 2012-03-13
# 2602    POINT (-85.86275 42.86122)     4999 2012-09-17     652 days 2014-07-01
# 3648    POINT (-94.42410 39.27451)     4999 2016-07-19     553 days 2018-01-23
# 2981   POINT (-115.12464 36.26444)     4999 2016-11-18     606 days 2018-07-17
#
# [20000 rows x 8 columns]

# %%
# retrieve filenames within target folder
obj1 = pd.Series(os.listdir(os.path.join(os.getcwd(), '../..')))

# filter to objects of name convention
itemlist = obj1.loc[obj1.apply(lambda x: x.startswith('test_address'))]

# identify the most recent version
max_item = itemlist.apply(lambda x: x.split('.')[0].split('v')[1]).astype(int).max()

# %%
max_item+1
# Out:
# 2

# %%
# test output address history csv

tmp1 = tmp.sort_values(['user_id','start_date'])
tmp1
# Out:
#                                        Full_Addre  source_lon  source_lat  \
# 6972          18248 HILLSIDE LN, DOLAND, SD 57436  -98.048963   44.737366
# 1940              244 ELM ST, HILL CITY, SD 57745 -103.574269   43.932597
# 7425                  PO BOX 9823, BEND, OR 97708 -121.344782   43.978130
# 634     10208 Bluegrass Road, Knoxville, TN 37922  -84.106168   35.860066
# 14075  7338 SOUTH ALTON WAY, CENTENNIAL, CO 80112 -104.882937   39.583518
# ...                                           ...         ...         ...
# 6784         1057 LINCOLN ST SW, ALBANY, OR 97321 -123.122892   44.627669
# 2045             384 COURT ST, PLYMOUTH, MA 02360  -70.691150   41.978494
# 2602         5037 32ND AVE, HUDSONVILLE, MI 49426  -85.862753   42.861220
# 3648     2525 GLENN HENDREN DR, LIBERTY, MO 64068  -94.424104   39.274506
# 2981       5700 N BRUCE ST, N LAS VEGAS, NV 89081 -115.124639   36.264440
#
#                           geometry  user_id start_date end_duration   end_date
# 6972    POINT (-98.04896 44.73737)        1 2004-12-09     604 days 2006-08-05
# 1940   POINT (-103.57427 43.93260)        1 2006-02-04     946 days 2008-09-07
# 7425   POINT (-121.34478 43.97813)        1 2018-07-12     456 days 2019-10-11
# 634     POINT (-84.10617 35.86007)        2 2001-05-11     790 days 2003-07-10
# 14075  POINT (-104.88294 39.58352)        2 2004-01-09     876 days 2006-06-03
# ...                            ...      ...        ...          ...        ...
# 6784   POINT (-123.12289 44.62767)     4999 2006-04-17     599 days 2007-12-07
# 2045    POINT (-70.69115 41.97849)     4999 2010-05-21     662 days 2012-03-13
# 2602    POINT (-85.86275 42.86122)     4999 2012-09-17     652 days 2014-07-01
# 3648    POINT (-94.42410 39.27451)     4999 2016-07-19     553 days 2018-01-23
# 2981   POINT (-115.12464 36.26444)     4999 2016-11-18     606 days 2018-07-17
#
# [20000 rows x 8 columns]

# %%
output_path = os.path.join(os.getcwd(), '../..','test_address_{0}_v{1}.csv'.format(tmp.shape[0], max_item+1))
output_path
# Out:
# '/Users/jphuong/CLAD_Geospatial/notebooks/../../test_address_20000_v2.csv'

# %%
tmp1.to_csv(output_path, index=False)
